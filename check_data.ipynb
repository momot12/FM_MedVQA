# %%
from datasets import load_dataset

cache_dir = 'eepy/datasets/'
# VQA-RAD
# 'https://huggingface.co/datasets/flaviagiammarino/vqa-rad'
ds_vqa_rad = load_dataset("flaviagiammarino/vqa-rad", cache_dir=cache_dir)

# SLAKE English
ds_slake = load_dataset("mdwiratathya/SLAKE-vqa-english", cache_dir=cache_dir)

# PathVQA
ds_pathVQA = load_dataset("flaviagiammarino/path-vqa", cache_dir=cache_dir)

# %%
ds_vqa_rad
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'question', 'answer'],
#         num_rows: 1793
#     })
#     test: Dataset({
#         features: ['image', 'question', 'answer'],
#         num_rows: 451
#     })
# })

# %%
ds_vqa_rad['train']
# Out:
# Dataset({
#     features: ['image', 'question', 'answer'],
#     num_rows: 1793
# })

# %%
from PIL import Image

# Load the image data from the dataset
image = ds_vqa_rad['train']['image'][0]
question = ds_vqa_rad['train']['question'][0]
answer = ds_vqa_rad['train']['answer'][0]

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=566x555>

# %%
question
# Out:
# 'are regions of the brain infarcted?'

# %%
answer
# Out:
# 'yes'
